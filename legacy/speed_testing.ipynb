# %%
import torch
import jax
import jax.numpy as jnp
import time
from env_jax import ParticleEnvJAX

n_steps = 100
n_env = 10000
n_particles = 50
dt = 0.01
key = jax.random.PRNGKey(0)

# %%
# ---------------- JAX ---------
env_jax = ParticleEnvJAX(key, n_env=n_env, n_particles=n_particles, dt=dt)
start = time.time()
for _ in range(n_steps):
    env_jax.step()
jax.device_get(env_jax.pos)  # sync computation
print("JAX:", time.time() - start, "s")
del env_jax
# Out:
# JAX: 0.6312322616577148 s

# %%
# ---------------- PyTorch standard ----------------
torch.cuda.empty_cache()
env = ParticleEnv(n_env=n_env, n_particles=n_particles, device='cuda')
start = time.time()
for _ in range(n_steps):
    env.step(dt=dt)
torch.cuda.synchronize()
print("PyTorch standard:", time.time()-start, "s")
del env; torch.cuda.empty_cache()

# ---------------- PyTorch prealloc ----------------

# %%
env_pre = ParticleEnvPreAlloc(n_env=n_env, n_particles=n_particles, device='cuda')
start = time.time()
for _ in range(n_steps):
    env_pre.step(dt=dt)
torch.cuda.synchronize()
print("PyTorch prealloc:", time.time()-start, "s")
del env_pre; torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       2 start = time.time()
#       3 for _ in range(n_steps):
# ----> 4     env_pre.step(dt=dt)
#       5 torch.cuda.synchronize()
#       6 print("PyTorch prealloc:", time.time()-start, "s")
#
# File c:\Users\mw2799\Documents\particles\env_torch_prealloc.py:34, in ParticleEnvPreAlloc.step(self, dt, box_size, k)
#      32 self.r.copy_(self.pos[:, :, None, :] - self.pos[:, None, :, :])
#      33 self.dist3.copy_(self.r.norm(dim=-1, keepdim=True).pow(3) + eps)
# ---> 34 self.qiqj.copy_((self.charge * self.charge.transpose(1,2))[:, :, :, None])
#      36 # force
#      37 self.F.copy_(self.r * self.qiqj / self.dist3)
#
# KeyboardInterrupt:

# %%
import importlib.util

for pkg in ["taichi", "pybullet", "mujoco", "jax", "hoomd"]:
    print(pkg, importlib.util.find_spec(pkg) is not None)
# Out:
# taichi False
# pybullet False
# mujoco False
# jax True
# hoomd False
