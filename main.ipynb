# %%
import torch
import jax
import jax.numpy as jnp
import time
from env_jax import ParticleEnvJAX
from make_video import watch

# %%
from predictive_latent import JaxNetwork

# %%
key = jax.random.PRNGKey(0)
env = ParticleEnvJAX(key, n_env=10000, n_particles=10, dt=0.01,
                     interaction_strength=0.2, wall_force_coeff=1000, damping=1, vel_range=2)

# Flatten state: positions + velocities
def flatten_state(pos, vel):
    return jnp.concatenate([pos.reshape(pos.shape[0], -1), vel.reshape(vel.shape[0], -1)], axis=-1)

state_dim = env.n_particles * 2 * 2  # pos + vel for each particle
net = JaxNetwork(key, [state_dim, 128, 128, state_dim])  # predict next state

# %%
lr = 1e-3
n_steps = 100000

for step in range(n_steps):
    # 1. Take one environment step
    env.step()
    
    # 2. Get current & next state
    s_n = flatten_state(env.pos, env.vel)
    env.step()
    s_n_next = flatten_state(env.pos, env.vel)
    
    # 3. Update network params (SGD)
    net.params = net.sgd_step(net.params, s_n, s_n_next, lr=lr)
    
    # 4. Optionally measure MSE loss for monitoring
    if step % 50 == 0:
        loss_val = JaxNetwork._loss(net.params, s_n, s_n_next)
        print(f"Step {step}, MSE: {loss_val:.5f}")
# Out:
# Step 0, MSE: 1.08487
# Step 50, MSE: 1.18709
# Step 100, MSE: 1.17319
# Step 150, MSE: 1.15927
# Step 200, MSE: 1.14735
# Step 250, MSE: 1.13796
# Step 300, MSE: 1.12496
# Step 350, MSE: 1.11725
# Step 400, MSE: 1.10736
# Step 450, MSE: 1.09895
# Step 500, MSE: 1.09198
# Step 550, MSE: 1.08512
# Step 600, MSE: 1.07533
# Step 650, MSE: 1.06747
# Step 700, MSE: 1.06462
# Step 750, MSE: 1.05956
# Step 800, MSE: 1.05316
# Step 850, MSE: 1.04727
# Step 900, MSE: 1.03942
# Step 950, MSE: 1.03591
# Step 1000, MSE: 1.03286
# Step 1050, MSE: 1.02911
# Step 1100, MSE: 1.02353
# Step 1150, MSE: 1.02073
# Step 1200, MSE: 1.01800
# Step 1250, MSE: 1.01184
# Step 1300, MSE: 1.00814
# Step 1350, MSE: 1.00344
# Step 1400, MSE: 1.00226
# Step 1450, MSE: 0.99677
# Step 1500, MSE: 0.99456
# Step 1550, MSE: 0.99025
# Step 1600, MSE: 0.98916
# Step 1650, MSE: 0.98597
# Step 1700, MSE: 0.98162
# Step 1750, MSE: 0.97933
# Step 1800, MSE: 0.97646
# Step 1850, MSE: 0.97363
# Step 1900, MSE: 0.97134
# Step 1950, MSE: 0.96751
# Step 2000, MSE: 0.96522
# Step 2050, MSE: 0.96423
# Step 2100, MSE: 0.95853
# Step 2150, MSE: 0.95913
# Step 2200, MSE: 0.95657
# Step 2250, MSE: 0.95412
# Step 2300, MSE: 0.95164
# Step 2350, MSE: 0.94811
# Step 2400, MSE: 0.94556
# Step 2450, MSE: 0.94224
# Step 2500, MSE: 0.94302
# Step 2550, MSE: 0.93857
# Step 2600, MSE: 0.93659
# Step 2650, MSE: 0.93405
# Step 2700, MSE: 0.93320
# Step 2750, MSE: 0.93102
# Step 2800, MSE: 0.92943
# Step 2850, MSE: 0.92775
# Step 2900, MSE: 0.92418
# Step 2950, MSE: 0.92410
# Step 3000, MSE: 0.92152
# Step 3050, MSE: 0.91801
# Step 3100, MSE: 0.91681
# Step 3150, MSE: 0.91693
# Step 3200, MSE: 0.91271
# Step 3250, MSE: 0.91359
# Step 3300, MSE: 0.90983
# Step 3350, MSE: 0.91005
# Step 3400, MSE: 0.90525
# Step 3450, MSE: 0.90596
# Step 3500, MSE: 0.90235
# Step 3550, MSE: 0.90123
# Step 3600, MSE: 0.89665
# Step 3650, MSE: 0.89718
# Step 3700, MSE: 0.89482
# Step 3750, MSE: 0.89536
# Step 3800, MSE: 0.89237
# Step 3850, MSE: 0.89274
# Step 3900, MSE: 0.88845
# Step 3950, MSE: 0.88680
# Step 4000, MSE: 0.88576
# Step 4050, MSE: 0.88394
# Step 4100, MSE: 0.88233
# Step 4150, MSE: 0.88020
# Step 4200, MSE: 0.87822
# Step 4250, MSE: 0.87753
# Step 4300, MSE: 0.87236
# Step 4350, MSE: 0.87397
# Step 4400, MSE: 0.87404
# Step 4450, MSE: 0.87292
# Step 4500, MSE: 0.86759
# Step 4550, MSE: 0.86653
# Step 4600, MSE: 0.86779
# Step 4650, MSE: 0.86414
# Step 4700, MSE: 0.86315
# Step 4750, MSE: 0.85903
# Step 4800, MSE: 0.86041
# Step 4850, MSE: 0.85765
# Step 4900, MSE: 0.85418
# Step 4950, MSE: 0.85459
# Step 5000, MSE: 0.85363
# Step 5050, MSE: 0.85138
# Step 5100, MSE: 0.84961
# Step 5150, MSE: 0.84790
# Step 5200, MSE: 0.84614
# Step 5250, MSE: 0.84265
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#      11 s_n_next = flatten_state(env.pos, env.vel)
#      13 # 3. Update network params (SGD)
# ---> 14 net.params = net.sgd_step(net.params, s_n, s_n_next, lr=lr)
#      16 # 4. Optionally measure MSE loss for monitoring
#      17 if step % 50 == 0:
#
# KeyboardInterrupt:

# %%
watch(env, model=net, n_steps=200, dt_pred=5, scale=600, output_file="predicted.mp4", fps=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 watch(env, model=net, n_steps=200, dt_pred=5, scale=600, output_file="predicted.mp4", fps=30)
#
# File h:\Documents\particles\particles\make_video.py:44, in watch(env, model, n_steps, dt_pred, scale, output_file, fps, radius)
#      42 pred_state = state_jax
#      43 for _ in range(dt_pred):
# ---> 44     pred_state = model.forward(model.params, pred_state)
#      45 pred_pos = np.array(pred_state[:, :2])
#      47 px_pred = ((proportion * pred_pos[:,0] + 1)/2 * (scale-1)).astype(int)
#
#     [... skipping hidden 14 frame]
#
# File h:\Documents\particles\particles\predictive_latent.py:25, in JaxNetwork._forward(params, x)
#      22 @staticmethod
#      23 def _forward(params, x):
#      24     for i, (W, b) in enumerate(params):
# ---> 25         x = x @ W + b
#      26         if i < len(params) - 1:
#      27             x = jax.nn.relu(x)
#
#     [... skipping hidden 1 frame]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\jax\_src\numpy\lax_numpy.py:4586, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#    4584 if not isinstance(other, _accepted_binop_types):
#    4585   return NotImplemented
# -> 4586 return binary_op(self, other)
#
#     [... skipping hidden 7 frame]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\jax\_src\numpy\lax_numpy.py:2793, in matmul(a, b, precision)
#    2791 a = lax.squeeze(a, tuple(a_squeeze))
#    2792 b = lax.squeeze(b, tuple(b_squeeze))
# -> 2793 out = lax.dot_general(
#    2794   a, b, (((ndim(a) - 1,), (ndim(b) - 1 - b_is_mat,)), (a_batch, b_batch)),
#    2795   precision=precision)
#    2796 return lax.transpose(out, perm)
#
#     [... skipping hidden 7 frame]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\jax\_src\lax\lax.py:2420, in _dot_general_shape_rule(lhs, rhs, dimension_numbers, precision, preferred_element_type)
#    2417 if not core.symbolic_equal_shape(lhs_contracting_shape, rhs_contracting_shape):
#    2418   msg = ("dot_general requires contracting dimensions to have the same "
#    2419          "shape, got {} and {}.")
# -> 2420   raise TypeError(msg.format(lhs_contracting_shape, rhs_contracting_shape))
#    2422 return _dot_general_shape_computation(lhs.shape, rhs.shape, dimension_numbers)
#
# TypeError: dot_general requires contracting dimensions to have the same shape, got (4,) and (40,).

# %%
lr = 1e-3
n_steps = 500

# %%
env.step()
s_n = flatten_state(env.pos, env.vel)
env.step()
s_n_next = flatten_state(env.pos, env.vel)

# %%
net.params = net.sgd_step(net.params, s_n, s_n_next, lr=lr)

# %%
s_n.shape
# Out:
# (10, 40)

# %%
key = jax.random.PRNGKey(0)
n_steps = 1000

# %%
env_jax = ParticleEnvJAX(key, n_env=100000, n_particles=10, dt=0.001,interaction_strength=0.05, damping=0.99,wall_force_coeff=5,vel_range=1)
start = time.time()
for _ in range(n_steps):
    env_jax.step()
jax.device_get(env_jax.pos)  # sync computation
print("JAX:", time.time() - start, "s")
del env_jax
# Out:
# JAX: 0.6337120532989502 s

# %%
env_jax = ParticleEnvJAX(key, n_env=1, n_particles=10, dt=0.01,interaction_strength=0.2, wall_force_coeff=1000, damping=1, vel_range=2)

# %%
env_jax.vel
# Out:
# DeviceArray([[[-0.54249716, -1.6424489 ],
#               [ 0.5954504 ,  0.06958485],
#               [ 0.95345116,  0.58791924],
#               [-0.5985122 ,  0.82822037],
#               [-1.9103389 ,  1.6309776 ],
#               [ 0.02079391,  1.5843863 ],
#               [ 1.4163332 ,  0.59623003],
#               [ 1.2774882 ,  0.5948634 ],
#               [-0.7074404 , -1.7265964 ],
#               [ 1.2423677 , -0.7262883 ]]], dtype=float32)

# %%
env_jax.pos = env_jax.pos.at[0,0,0].set(0.78)

# %%
watch(env_jax, n_steps=1000, scale=1000, output_file="simulation.mp4", fps=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 watch(env_jax, n_steps=1000, scale=1000, output_file="simulation.mp4", fps=30)
#
# File h:\Documents\particles\particles\make_video.py:13, in watch(env, n_steps, scale, output_file, fps, radius)
#      11 for step in range(n_steps):
#      12     env.step()
# ---> 13     env.measure_KE()
#      14     env.measure_PE()
#      15     total_energy = env.KE + env.PE
#
# File h:\Documents\particles\particles\env_jax.py:88, in ParticleEnvJAX.measure_KE(self)
#      87 def measure_KE(self):
# ---> 88     self.KE = self._jit_measure_KE(self.vel)
#
#     [... skipping hidden 13 frame]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\jax\linear_util.py:168, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     165 gen = gen_static_args = out_store = None
#     167 try:
# --> 168   ans = self.f(*args, **dict(self.params, **kwargs))
#     169 except:
#     170   # Some transformations yield from inside context managers, so we have to
#     171   # interrupt them before reraising the exception. Otherwise they will only
#     172   # get garbage-collected at some later time, running their cleanup tasks
#     173   # only after this exception is handled, which can corrupt the global
#     174   # state.
#     175   while stack:
#
# TypeError: _measure_KE() missing 1 required positional argument: 'vel'

# %%
env_jax.pos
# Out:
# DeviceArray([[[ 0.8177988 , -0.73890257],
#               [-0.20882733, -0.86405367]]], dtype=float32)
